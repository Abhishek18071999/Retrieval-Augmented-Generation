# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter,Language
from pprint import pp

# %%
python_code = """
import numpy as np
from typing import List, Optional

def calculate_mean(numbers: List[float]) -> float:
    '''Calculate the arithmetic mean of a list of numbers.
    
    Args:
        numbers: List of numerical values
        
    Returns:
        The mean value
    '''
    return sum(numbers) / len(numbers)

def calculate_median(numbers: List[float]) -> float:
    '''Calculate the median of a list of numbers.'''
    sorted_nums = sorted(numbers)
    n = len(sorted_nums)
    mid = n // 2
    
    if n % 2 == 0:
        return (sorted_nums[mid - 1] + sorted_nums[mid]) / 2
    return sorted_nums[mid]

class StatisticalAnalyzer:
    '''A class for performing statistical analysis on datasets.'''
    
    def __init__(self, data: List[float]):
        self.data = data
        self.mean = None
        self.median = None
    
    def analyze(self) -> dict:
        '''Perform complete statistical analysis.'''
        self.mean = calculate_mean(self.data)
        self.median = calculate_median(self.data)
        
        return {
            'mean': self.mean,
            'median': self.median,
            'count': len(self.data)
        }
    
    def get_summary(self) -> str:
        '''Return a formatted summary of the analysis.'''
        if self.mean is None:
            self.analyze()
        
        return f"Mean: {self.mean:.2f}, Median: {self.median:.2f}"

def main():
    '''Main execution function.'''
    data = [1.5, 2.3, 3.7, 4.2, 5.1]
    analyzer = StatisticalAnalyzer(data)
    results = analyzer.analyze()
    print(analyzer.get_summary())

if __name__ == "__main__":
    main()
"""

# %%
print(python_code)
# Out:
# import numpy as np
# from typing import List, Optional
#
# def calculate_mean(numbers: List[float]) -> float:
#     '''Calculate the arithmetic mean of a list of numbers.
#
#     Args:
#         numbers: List of numerical values
#
#     Returns:
#         The mean value
#     '''
#     return sum(numbers) / len(numbers)
#
# def calculate_median(numbers: List[float]) -> float:
#     '''Calculate the median of a list of numbers.'''
#     sorted_nums = sorted(numbers)
#     n = len(sorted_nums)
#     mid = n // 2
#
#     if n % 2 == 0:
#         return (sorted_nums[mid - 1] + sorted_nums[mid]) / 2
#     return sorted_nums[mid]
#
# class StatisticalAnalyzer:
#     '''A class for performing statistical analysis on datasets.'''
#
#     def __init__(self, data: List[float]):
#         self.data = data
#         self.mean = None
#         self.median = None
#
#     def analyze(self) -> dict:
#         '''Perform complete statistical analysis.'''
# ...

# %%
#create the text splitter
python_Splitter = RecursiveCharacterTextSplitter.from_language(language=Language.PYTHON,
                                                               chunk_size= 750,
                                                               chunk_overlap = 100)

# %%
##split the code
code_chunks = python_Splitter.split_text(python_code)

# %%
pp(code_chunks)
# Out:
# ['import numpy as np\n'
#  'from typing import List, Optional\n'
#  '\n'
#  'def calculate_mean(numbers: List[float]) -> float:\n'
#  "    '''Calculate the arithmetic mean of a list of numbers.\n"
#  '\n'
#  '    Args:\n'
#  '        numbers: List of numerical values\n'
#  '\n'
#  '    Returns:\n'
#  '        The mean value\n'
#  "    '''\n"
#  '    return sum(numbers) / len(numbers)\n'
#  '\n'
#  'def calculate_median(numbers: List[float]) -> float:\n'
#  "    '''Calculate the median of a list of numbers.'''\n"
#  '    sorted_nums = sorted(numbers)\n'
#  '    n = len(sorted_nums)\n'
#  '    mid = n // 2\n'
#  '\n'
#  '    if n % 2 == 0:\n'
#  '        return (sorted_nums[mid - 1] + sorted_nums[mid]) / 2\n'
#  '    return sorted_nums[mid]',
#  'class StatisticalAnalyzer:\n'
#  "    '''A class for performing statistical analysis on datasets.'''\n"
#  '\n'
#  '    def __init__(self, data: List[float]):\n'
#  '        self.data = data\n'
#  '        self.mean = None\n'
# ...

# %%
from termcolor import colored, COLORS
from random import choice

# %%
def display_chunks(chunks):
    color_list = list(COLORS.keys())[12:8]
    print(f"Total number of chnuks: {len(chunks)}")
    for num, chunk in enumerate(chunks,1):
        print(f"Chunk : {num} : Length : {len(chunk)} chars")
        print(colored(text=chunk,color= choice(color_list)),end="\n\n")

# %%
display_chunks(chunks=code_chunks)
# Out:
# Total number of chnuks: 3
# Chunk : 1 : Length : 592 chars
# import numpy as np
# from typing import List, Optional
#
# def calculate_mean(numbers: List[float]) -> float:
#     '''Calculate the arithmetic mean of a list of numbers.
#
#     Args:
#         numbers: List of numerical values
#
#     Returns:
#         The mean value
#     '''
#     return sum(numbers) / len(numbers)
#
# def calculate_median(numbers: List[float]) -> float:
#     '''Calculate the median of a list of numbers.'''
#     sorted_nums = sorted(numbers)
#     n = len(sorted_nums)
#     mid = n // 2
#
#     if n % 2 == 0:
#         return (sorted_nums[mid - 1] + sorted_nums[mid]) / 2
#     return sorted_nums[mid]
#
# Chunk : 2 : Length : 743 chars
# class StatisticalAnalyzer:
#     '''A class for performing statistical analysis on datasets.'''
#
#     def __init__(self, data: List[float]):
#         self.data = data
#         self.mean = None
#         self.median = None
#
#     def analyze(self) -> dict:
# ...

# %%
python_Splitter.get_separators_for_language(language=Language.CSHARP)
# Out:
# ['\ninterface ',
#  '\nenum ',
#  '\nimplements ',
#  '\ndelegate ',
#  '\nevent ',
#  '\nclass ',
#  '\nabstract ',
#  '\npublic ',
#  '\nprotected ',
#  '\nprivate ',
#  '\nstatic ',
#  '\nreturn ',
#  '\nif ',
#  '\ncontinue ',
#  '\nfor ',
#  '\nforeach ',
#  '\nwhile ',
#  '\nswitch ',
#  '\nbreak ',
#  '\ncase ',
#  '\nelse ',
#  '\ntry ',
#  '\nthrow ',
#  '\nfinally ',
#  '\ncatch ',
#  '\n\n',
#  '\n',
#  ' ',
#  '']

# %% [markdown]
# ## JSON Data

# %%
json_data = {
    "statusCode": 200,
    "message": "POST Request successful.",
    "result": {
        "flightPassengerList": [
            {
                "bookingId": 62649,
                "referenceNumber": "CFR042662649",
                "title": "Mr",
                "firstName": "Hem",
                "lastName": "Kamli",
                "email": "care@travelterminus.com",
                "dob": "2013-11-20T00:00:00",
                "gender": "M",
                "ffNumber": "",
                "paxType": "ADT",
                "mobile": "9016888437",
                "passportNumber": "HEM123",
                "passengerNationality": "AL",
                "passportDOI": "2025-12-03T00:00:00",
                "passportDOE": "2026-12-31T00:00:00",
                "passportIssuedCountry": "IN",
                "seatPref": "",
                "mealPref": "",
                "paxId": 222467,
                "tickets": [],
                "extraBaggage": []
            }
        ],
        "clientFlightDetails": [
            {
                "searchIdentifier": "25be7b83-039b-4742-8d2f-682c299adb46",
                "validatingCarrier": "ET",
                "travelDate": "2026-06-24T16:10:00",
                "adtCount": 1,
                "chdCount": 0,
                "infCount": 0,
                "totalFare": 69971.36,
                "origin": "BLR",
                "destination": "DXB",
                "itineraryUniqueReference": "ET691ET600",
                "airFlightSegments": [
                    {
                        "airlinePnr": "",
                        "isReturn": "false",
                        "origin": "BLR",
                        "destination": "ADD",
                        "departureDateTime": "2026-06-24T16:10:00",
                        "arrivalDateTime": "2026-06-24T19:40:00",
                        "journeyDuration": "360",
                        "stopQuantity": "1",
                        "flightNumber": "691",
                        "operatingAirline": "ET",
                        "equipmentType": "7M8",
                        "bookingClass": "H",
                        "cabinClass": "ECONOMY",
                        "marketingAirline": "ET",
                        "departureTerminal": "2",
                        "arrivalTerminal": "2",
                        "isTechnicalStopOversAvailable": "false",
                        "operatingFlightNumber": "691",
                        "stopOverSegments": []
                    },
                    {
                        "airlinePnr": "",
                        "isReturn": "false",
                        "origin": "ADD",
                        "destination": "DXB",
                        "departureDateTime": "2026-06-24T21:45:00",
                        "arrivalDateTime": "2026-06-25T02:55:00",
                        "journeyDuration": "250",
                        "stopQuantity": "1",
                        "flightNumber": "600",
                        "operatingAirline": "ET",
                        "equipmentType": "77L",
                        "bookingClass": "H",
                        "cabinClass": "ECONOMY",
                        "marketingAirline": "ET",
                        "departureTerminal": "2",
                        "arrivalTerminal": "1",
                        "isTechnicalStopOversAvailable": "false",
                        "operatingFlightNumber": "600",
                        "stopOverSegments": []
                    }
                ],
                "fareRules": [
                    {
                        "paxType": "",
                        "airlineCode": "ET",
                        "cityPair": "BLR-ADD",
                        "ruleDetails": "PENALTIES\nUNLESS OTHERWISE SPECIFIED   NOTE - GENERAL RULE DOES NOT\nAPPLY\n  CHANGES\n    ANY TIME\n      CHARGE USD 100.00.\n    CHARGE USD 50.00 FOR NO-SHOW.\n  CANCELLATIONS\n    ANY TIME\n      CHARGE USD 150.00.\n    CHARGE USD 50.00 FOR NO-SHOW.\n         NOTE -\n          ALL APPLICABLE CONDITIONS STATED BELOW SHOULD BE\n          SATISFIED IN ADDITION TO CHARGES STATED ABOVE\n          CHANGES\n          --------------------------------------------------\n          ... A CHANGE IS A DATE/FLIGHT/ROUTING/BOOKING\n              CODE CHANGE.\n          ... CHANGE FEE APPLIES PER PASSENGER PER\n              TRANSACTION.\n          ... CHANGE FEE DOES NOT APPLY TO INFANT NOT\n              OCCUPYING A SEAT.\n          ... CHD/INF WITH A SEAT DISCOUNT DOES NOT APPLY\n              ON THE CHANGE/REROUTING FEES.\n          ... CHANGE IS PERMITTED WITHIN TICKET VALIDITY OF\n              ORIGINAL TICKET.\n          ... ONE FREE DATE CHANGE FOR INBOUND JOURNEY\n              PERMITTED IF REQUESTED TRAVEL DATE IS OUTSIDE\n            SYSTEM RANGE OR IF IT IS BEYOND 331 DAYS AT TIME\n            OF TICKETING. REMARK MUST BE INSERTED IN THE PNR\n           WITH THE REQUESTED INBOUND TRAVEL DATE AND THE\n           FREE CHANGE APPLIES ONLY IF THE TRAVEL DATE IS\n           THE SAME AT TIME OF RE BOOKING.\n          -------------------------------------------------\n          REROUTING----------------------------------------\n          REROUTING TO A SECTOR WITH EQUAL OR HIGHER\n          RBD/AMOUNT IS PERMITTED BY COLLECTING FARE\n          DIFFERENCE AND APPLICABLE REBOOKING FEE.\n          REROUTING TO A SECTOR WITH LOWER RBD/FARE IS\n          PERMITTED BUT RESIDUAL FARE DIFFERENCE WILL NOT\n          BE REFUNDED AND APPLICABLE REBOOKING FEE SHALL BE\n          COLLECTED.\n          FARE DIFFERENCE IS CALCULATED ON THE TOTAL OF\n          BASE FARE PLUS YR HENCE THE RESIDUAL YR CAN BE\n          USED TO OFFSET THE BASE FARE DIFFERENCE.\n          --------------------------------------------------\n          NO SHOW CONDITIONS\n          1. A NO-SHOW FOR A FLIGHT IS CONSIDERED WHEN A\n          PASSENGER FAILS TO USE AS BOOKED OR CANCEL THE\n          RESERVATION 24 HOURS BEFORE DEPARTURE OF THE\n          SCHEDULED FLIGHT.\n          2.THE NO SHOW FEE APPLIES ON TOP OF CHNAGE FEE OR\n          THE CANCELLATION/REFUND FEE AS APPLICABLE\n          3.FOR DATE CHANGE REQUESTS  MADE ON THE DAY OF\n          TRAVEL THE APPLICABLE NO SHOW FEE SHALL APPLY\n          4.UNLESS A RESERVATION IS CANCELLED OR A TICKET IS\n          EXCHANGED OR REFUNDED AT LEAST 24 HOURS BEFORE\n          THE SCHEDULED DEPARTURE DATE IT WILL BE CONSIDERED\n          CONSIDERED AS A NO SHOW\n          5.NO SHOW  FEE IS NON COMMISSIONABLE\n          6.IN CASE OF NO SHOW AT THE GATE AFTER CHECKED IN\n          THE FLIGHT TICKET IS INVALID FOR TRAVEL OR REFUND\n          7.GATE NO SHOW PENALTY  IS WAIVED FOR NO SHOW\n          PASSENGERS AT ADD AIRPORT ONLY. BUT ALL OTHER NO\n          SHOW AND PENALTY FEE APPLY.\n          --------------------------------------------------\n          UPGRADES - APPLICABLE ONLY IF CHANGES ARE\n          PERMITTED.\n          1.UPGRADES TO HIGHER FARE IN THE SAME CABIN.\n            RECALCULATE THE FARE FROM THE POINT OF ORIGIN\n            PROVIDED THE FARE RULE CONDITIONS OF THE\n            HIGHER FARE ARE MET.\n            COLLECT THE FARE DIFFERENCE AND CHANGE FEE.\n            IF THE UPGRADED TICKET IS SUBSEQUENTLY\n            CANCELLED THE ORIGINAL CHARGE WILL APPLY.\n          2.UPGRADES TO HIGHER FARE IN A HIGHER CABIN.\n            RECALCULATE THE FARE FROM THE POINT OF ORIGIN\n            PROVIDED THE FARE RULE CONDITIONS OF THE HIGHER\n            FARE ARE MET.\n            COLLECT THE FARE DIFFERENCE AND ADDITIONAL TAX\n          IF ANY. CHANGE FEE IS\n            WAIVED FOR UPGRADE TO HIGHER CABIN.\n            IF THE UPGRADED TICKET IS SUBSEQUENTLY\n            CANCELLED THE ORIGINAL CHARGE WILL APPLY.\n          ------------------------------------------------\n          ADDITIONAL GST WILL APPLY FOR ANY PENALTY AMOUNT\n          AS PER THE APPLICABLE GST LAW\n          5 PERCENT FOR ECONOMY AND 18 PERCENT FOR BUSINESS\n          IS COLLECTED ON ANY ADC AND PENALTY COLLECTION.\n          NO SHOW AND REFUND PENALTY IS NOW 5 PERCENT FOR\n          ECONOMY AND 18 PERCENT FOR BUSINESS.\n          K3 REFUND APPLICABILITY - AS PER THE INDIAS\n          FINANCIAL\n          K3 CAN BE REFUNDED ON BEFORE 30SEP AFTER INDIA\n          FINANCIAL YEAR CLOSED.\n          --------------------------------------------------\n          --------------------------------------------------\n          VOLUNTARY DOWNGRADE - NO REFUNDS IN CASE OF\n          VOLUNTARY DOWNGRADE.\n          IN CASE OF VOLUNTARY DOWN GRADE THE RESIDUAL\n          AMOUNT CAN NOT BE USED FOR CHANGE PENALTY PAYMENT.\n          --------------------------------------------------\n          PENALTY FEE APPLICATION\n          1.ANY TIME WHEN THIS FARE IS COMBINED WITH\n            ANOTHER FARE AND ONLY ONE FARE COMPONENT IS\n            CHANGED THE PENALTY CONDITIONS OF THE\n          CHANGED FARE COMPONENT WILL APPLY.\n          2.ANY TIME WHEN MORE THAN ONE FARE COMPONENT IS\n            BEING CHANGED THE HIGHEST PENALTY OF\n          ALL CHANGED FARE COMPONENTS WILL APPLY.\n          3.INCASE OF THROUGH FARES IF ONLY THE DOMESTIC\n          SECTOR IS CHANGED PENALITY OF THE DOMESTIC FARE\n          WILL APPLY.\n          --------------------------------------------------\n          REPRICING CONDITIONS\n          A.BEFORE DEPARTURE / FULLY UNUTILISED TICKETS\n            1.REISSUE / REVALIDATION\n              IN THE EVENT OF VOLUNTARY CHANGES TO ANY\n              FLIGHT/DATE ON THE ITINERARY TICKET HAS TO BE\n              REISSUED AND COLLECT ANY FARE DIFFERENCE AS\n              AN ADC. THE FARES FOR THE PASSENGER JOURNEY\n              SHALL BE RECALCULATED FROM THE POINT OF\n              ORIGIN BASED ON THE DATE OF REISSUE.\n          B.AFTER DEPARTURE / PARTIALLY UTILISED TICKETS\n            AFTER COMMENCEMENT OF THE FIRST SECTOR OF THE\n            JOURNEY OR THE JOURNEY PERFORMED TILL THE\n            TURNAROUND / FARE BREAK POINT.\n              IN THE EVENT OF VOLUNTARY CHANGES AFTER\n              COMMENCEMENT OF TRAVEL THE FARES FOR THE\n              PASSENGER JOURNEY SHALL BE RECALCULATED FROM\n              THE POINT OF ORIGIN IN ACCORDANCE WITH THE\n              FARES IN EFFECT ON THE DATE OF ORIGINAL\n              TICKET ISSUANCE.\n              APPLICABLE CHANGE FEES TO BE COLLECTED.\n          C.FOR A PASSENGER NOT TO BE CONSIDERED A NO SHOW\n          THE TICKET HAS TO BE EXCHANGED AT LEAST A DAY\n          BEFORE THE SCHEDULED DEPARTURE DATE\n          --------------------------------------------------\n          CANCELLATION / REFUNDS\n          ... CANCELLATION / REFUND FEES ARE NOT\n              COMMISSIONABLE.\n          ... CANCELLATION FEE DOES NOT APPLY TO INFANT NOT\n              OCCUPYING A SEAT.\n          --------------------------------------------------\n          CANCELLATION / REFUNDS AGAINST UPGRADES -\n          IF THE UPGRADED TICKET IS SUBSEQUENTLY CANCELLED\n          THE ORIGINAL CHARGE WILL APPLY.\n          --------------------------------------------------\n          OUT OF SEQUENCE TICKETS -\n          UTILIZATION OF TICKETS OUT OF SEQUENCE IS NOT\n          PERMITTED IF IN ANY CASE TICKETS IS UTILIZED OUT\n          OF SEQUENCE NO REFUND OF FARE AND THE CARRIER\n          IMPOSED SURCHARGE -YR/YQ.\n          --------------------------------------------------\n          REFUNDABILITY OF K3 TAX IS AS PER THE LATEST\n          CIRCULAR ON K3 TAX\n          --------------------------------------------------\n          A.WHEN OUTBOUND AND INBOUND FARES ARE REFUNDABLE.\n            WHEN COMBINING FARES THAT HAVE CANCELLATION\n            FEES THE HIGHEST CANCELLATION FEE OF EACH\n            CANCELLED PRICING UNIT APPLIES.\n            1.BEFORE DEPARTURE / FULLY UNUTILISED TICKETS\n          ... DEDUCT THE APPLICABLE HIGHEST CANCELLATION\n              FEE FROM THE TOTAL OF THE BASE FARE AND\n              CARRIER IMPOSED SURCHARGE - YR.\n          ... REFUND THE RESIDUAL AMOUNT ALONG WITH THE\n              REFUNDABLE GOVERNMENT TAXES.\n          ... CARRIER IMPOSED SERVICE CHARGE - YQ IS NOT\n              REFUNDABLE.\n            2.AFTER DEPARTURE / PARTIALLY UTILISED TICKETS -\n              AFTER COMMENCEMENT OF THE FIRST SECTOR OF THE\n              JOURNEY.\n          ..... DEDUCT ONE WAY FARE WITH SAME RBD FOR THE\n          USED SECTOR.\n          ... COLLECT APPLICABLE CANCELLATION FEE AND\n              THE CARRIER IMPOSED SURCHARGE - YR FOR THE\n              JOURNEY PERFORMED. DEDUCT NON-REFUNDABLE\n              TAXES.\n          ... REFUND THE CARRIER IMPOSED SURCHARGE - YR AND\n              UNUTILISED GOVERNMENT TAXES FOR THE PORTION\n              OF THE JOURNEY NOT PERFORMED.\n          ... NO REFUND OF FARE AND CARRIER IMPOSED\n              SURCHARGE - YR IF JOURNEY PERFORMED BEYOND\n              THE TURNAROUND/FARE BREAK POINT.\n          ... CARRIER IMPOSED SERVICE CHARGE - YQ IS NOT\n              REFUNDABLE.\n          --------------------------------------------------\n          B.WHEN OUTBOUND AND INBOUND FARES ARE NON -\n            REFUNDABLE.\n          ... NO REFUND OF THE FARE AND CARRIER IMPOSED\n              FEES - YQ AND YR.\n          ... DEDUCT NON-REFUNDABLE TAXES.\n          ... IF NON- REFUNDABLE FARES REISSUED TO A\n              REFUNDABLE FARE THE ORIGINAL PAID FARE AND\n              CARRIER IMPOSED FEES - YQ AND YR WILL BE NON-\n              REFUNDABLE.\n          --------------------------------------------------\n          C.COMBINATION OF REFUNDABLE AND NON-REFUNDABLE\n            FARES.\n            1.BEFORE DEPARTURE/FULLY UNUTILISED TICKETS.\n          ... DEDUCT THE NON-REFUNDABLE FARE PAID AND THE\n              CANCELLATION FEE OF THE REFUNDABLE FARE.\n          ... DEDUCT NON-REFUNDABLE TAXES.\n          ... CARRIER IMPOSED FEES - YQ AND YR ARE NOT\n              REFUNDABLE.\n            2.AFTER DEPARTURE / PARTIALLY UTILISED TICKETS -\n              AFTER COMMENCEMENT OF THE FIRST SECTOR OF THE\n              JOURNEY.\n            2.1 IF OUTBOUND FARE COMPONENT IS NON-\n              REFUNDABLE.\n          ..... DEDUCT ONE WAY FARE WITH EQUAL OR\n                HIGHER RBD FOR THE USED SECTOR.\n          ..... COLLECT THE CANCELLATION FEE OF THE\n                REFUNDABLE FARE.\n          ..... DEDUCT NON-REFUNDABLE TAXES.\n          ..... CARRIER IMPOSED FEES YQ AND YR ARE NOT\n                REFUNDABLE.\n            2.2 IF INBOUND FARE COMPONENT IS NON-REFUNDABLE.\n          ..... NO REFUND OF THE FARE AND CARRIER IMPOSED\n                FEES - YQ AND YR.\n          ..... DEDUCT NON-REFUNDABLE TAXES.\n          ..... NO REFUND OF FARE AND CARRIER IMPOSED\n                SURCHARGE - YQ IF JOURNEY PERFORMED BEYOND\n                THE TURNAROUND/FARE BREAK POINT.\n          --------------------------------------------------\n          WAIVERS\n          1.WAIVED FOR DEATH OF PASSENGER OR IMMEDIATE\n          FAMILY MEMBER.\n            A COPY OF VALID DEATH CERTIFICATE ISSUED BY A\n            COMPETENT MEDICAL AUTHORITY IS REQUIRED.\n          2.NO WAIVER APPLICABLE FOR ILLNESS OF PASSENGER\n            OR FAMILY MEMBER.\n          3.CONTACT ET LOCAL OFFICE FOR WAIVERS DEFINED\n            ABOVE.\n          --------------------------------------------------\n          PER THE  US  D.O.T   RULE  FOR TICKETS PURCHASED\n          IN THE USA  FULL REFUND WITHOUT PENALTY  IS\n          PERMITTED IF REQUEST IS MADE WITHIN 24 HOURS OF\n          TICKET ISSUANCE\n          -------------------------------------------------\n            PENALITY WAIVER FOR REFUND\n          1.PER THE BRAZILIAN LEGISLATION FOR TICKETS\n          PURCHASED IN THE BRAZIL FULL REFUND WITHOUT\n          PENALTY IS PERMITTED IF REQUEST IS MADE WITHIN 24\n          HOURS OF TICKET ISSUANCE ON GDS.\n          2.PER THE BRAZILIAN LEGISLATION FOR TICKETS\n          PURCHASED IN THE BRAZIL FULL REFUND WITHOUT\n          PENALTY IS PERMITTED IF REQUEST IS MADE WITHIN 7\n          DAYS OF TICKET ISSUANCE VIA ANY ELECTRONIC\n          CHANNELS SUCH AS OTAS/PHONES/EMAIL/MOBILE/WEB.\nHIP/MILEAGE EXCEPTIONS\nUNLESS OTHERWISE SPECIFIED\n  THE HIGHER INTERMEDIATE POINT RULE DOES NOT APPLY FOR\n  CONNECTIONS.\n  AND - THE HIGHER INTERMEDIATE POINT RULE DOES NOT APPLY\n        FOR STOPOVERS.\nTICKET ENDORSEMENT\nUNLESS OTHERWISE SPECIFIED\n  THE ORIGINAL AND THE REISSUED TICKET MUST BE ANNOTATED -\n  NON-ENDO/PENALTIES APPLY - IN THE ENDORSEMENT BOX.",
                        "fareType": ""
                    },
                    {
                        "paxType": "",
                        "airlineCode": "ET",
                        "cityPair": "ADD-DXB",
                        "ruleDetails": "PENALTIES\nUNLESS OTHERWISE SPECIFIED   NOTE - GENERAL RULE DOES NOT\nAPPLY\n  CHANGES\n    ANY TIME\n      CHARGE USD 100.00.\n    CHARGE USD 50.00 FOR NO-SHOW.\n  CANCELLATIONS\n    ANY TIME\n      CHARGE USD 150.00.\n    CHARGE USD 50.00 FOR NO-SHOW.\n         NOTE -\n          ALL APPLICABLE CONDITIONS STATED BELOW SHOULD BE\n          SATISFIED IN ADDITION TO CHARGES STATED ABOVE\n          CHANGES\n          --------------------------------------------------\n          ... A CHANGE IS A DATE/FLIGHT/ROUTING/BOOKING\n              CODE CHANGE.\n          ... CHANGE FEE APPLIES PER PASSENGER PER\n              TRANSACTION.\n          ... CHANGE FEE DOES NOT APPLY TO INFANT NOT\n              OCCUPYING A SEAT.\n          ... CHD/INF WITH A SEAT DISCOUNT DOES NOT APPLY\n              ON THE CHANGE/REROUTING FEES.\n          ... CHANGE IS PERMITTED WITHIN TICKET VALIDITY OF\n              ORIGINAL TICKET.\n          ... ONE FREE DATE CHANGE FOR INBOUND JOURNEY\n              PERMITTED IF REQUESTED TRAVEL DATE IS OUTSIDE\n            SYSTEM RANGE OR IF IT IS BEYOND 331 DAYS AT TIME\n            OF TICKETING. REMARK MUST BE INSERTED IN THE PNR\n           WITH THE REQUESTED INBOUND TRAVEL DATE AND THE\n           FREE CHANGE APPLIES ONLY IF THE TRAVEL DATE IS\n           THE SAME AT TIME OF RE BOOKING.\n          -------------------------------------------------\n          REROUTING----------------------------------------\n          REROUTING TO A SECTOR WITH EQUAL OR HIGHER\n          RBD/AMOUNT IS PERMITTED BY COLLECTING FARE\n          DIFFERENCE AND APPLICABLE REBOOKING FEE.\n          REROUTING TO A SECTOR WITH LOWER RBD/FARE IS\n          PERMITTED BUT RESIDUAL FARE DIFFERENCE WILL NOT\n          BE REFUNDED AND APPLICABLE REBOOKING FEE SHALL BE\n          COLLECTED.\n          FARE DIFFERENCE IS CALCULATED ON THE TOTAL OF\n          BASE FARE PLUS YR HENCE THE RESIDUAL YR CAN BE\n          USED TO OFFSET THE BASE FARE DIFFERENCE.\n          --------------------------------------------------\n          NO SHOW CONDITIONS\n          1. A NO-SHOW FOR A FLIGHT IS CONSIDERED WHEN A\n          PASSENGER FAILS TO USE AS BOOKED OR CANCEL THE\n          RESERVATION 24 HOURS BEFORE DEPARTURE OF THE\n          SCHEDULED FLIGHT.\n          2.THE NO SHOW FEE APPLIES ON TOP OF CHNAGE FEE OR\n          THE CANCELLATION/REFUND FEE AS APPLICABLE\n          3.FOR DATE CHANGE REQUESTS  MADE ON THE DAY OF\n          TRAVEL THE APPLICABLE NO SHOW FEE SHALL APPLY\n          4.UNLESS A RESERVATION IS CANCELLED OR A TICKET IS\n          EXCHANGED OR REFUNDED AT LEAST 24 HOURS BEFORE\n          THE SCHEDULED DEPARTURE DATE IT WILL BE CONSIDERED\n          CONSIDERED AS A NO SHOW\n          5.NO SHOW  FEE IS NON COMMISSIONABLE\n          6.IN CASE OF NO SHOW AT THE GATE AFTER CHECKED IN\n          THE FLIGHT TICKET IS INVALID FOR TRAVEL OR REFUND\n          7.GATE NO SHOW PENALTY  IS WAIVED FOR NO SHOW\n          PASSENGERS AT ADD AIRPORT ONLY. BUT ALL OTHER NO\n          SHOW AND PENALTY FEE APPLY.\n          --------------------------------------------------\n          UPGRADES - APPLICABLE ONLY IF CHANGES ARE\n          PERMITTED.\n          1.UPGRADES TO HIGHER FARE IN THE SAME CABIN.\n            RECALCULATE THE FARE FROM THE POINT OF ORIGIN\n            PROVIDED THE FARE RULE CONDITIONS OF THE\n            HIGHER FARE ARE MET.\n            COLLECT THE FARE DIFFERENCE AND CHANGE FEE.\n            IF THE UPGRADED TICKET IS SUBSEQUENTLY\n            CANCELLED THE ORIGINAL CHARGE WILL APPLY.\n          2.UPGRADES TO HIGHER FARE IN A HIGHER CABIN.\n            RECALCULATE THE FARE FROM THE POINT OF ORIGIN\n            PROVIDED THE FARE RULE CONDITIONS OF THE HIGHER\n            FARE ARE MET.\n            COLLECT THE FARE DIFFERENCE AND ADDITIONAL TAX\n          IF ANY. CHANGE FEE IS\n            WAIVED FOR UPGRADE TO HIGHER CABIN.\n            IF THE UPGRADED TICKET IS SUBSEQUENTLY\n            CANCELLED THE ORIGINAL CHARGE WILL APPLY.\n          ------------------------------------------------\n          ADDITIONAL GST WILL APPLY FOR ANY PENALTY AMOUNT\n          AS PER THE APPLICABLE GST LAW\n          5 PERCENT FOR ECONOMY AND 18 PERCENT FOR BUSINESS\n          IS COLLECTED ON ANY ADC AND PENALTY COLLECTION.\n          NO SHOW AND REFUND PENALTY IS NOW 5 PERCENT FOR\n          ECONOMY AND 18 PERCENT FOR BUSINESS.\n          K3 REFUND APPLICABILITY - AS PER THE INDIAS\n          FINANCIAL\n          K3 CAN BE REFUNDED ON BEFORE 30SEP AFTER INDIA\n          FINANCIAL YEAR CLOSED.\n          --------------------------------------------------\n          --------------------------------------------------\n          VOLUNTARY DOWNGRADE - NO REFUNDS IN CASE OF\n          VOLUNTARY DOWNGRADE.\n          IN CASE OF VOLUNTARY DOWN GRADE THE RESIDUAL\n          AMOUNT CAN NOT BE USED FOR CHANGE PENALTY PAYMENT.\n          --------------------------------------------------\n          PENALTY FEE APPLICATION\n          1.ANY TIME WHEN THIS FARE IS COMBINED WITH\n            ANOTHER FARE AND ONLY ONE FARE COMPONENT IS\n            CHANGED THE PENALTY CONDITIONS OF THE\n          CHANGED FARE COMPONENT WILL APPLY.\n          2.ANY TIME WHEN MORE THAN ONE FARE COMPONENT IS\n            BEING CHANGED THE HIGHEST PENALTY OF\n          ALL CHANGED FARE COMPONENTS WILL APPLY.\n          3.INCASE OF THROUGH FARES IF ONLY THE DOMESTIC\n          SECTOR IS CHANGED PENALITY OF THE DOMESTIC FARE\n          WILL APPLY.\n          --------------------------------------------------\n          REPRICING CONDITIONS\n          A.BEFORE DEPARTURE / FULLY UNUTILISED TICKETS\n            1.REISSUE / REVALIDATION\n              IN THE EVENT OF VOLUNTARY CHANGES TO ANY\n              FLIGHT/DATE ON THE ITINERARY TICKET HAS TO BE\n              REISSUED AND COLLECT ANY FARE DIFFERENCE AS\n              AN ADC. THE FARES FOR THE PASSENGER JOURNEY\n              SHALL BE RECALCULATED FROM THE POINT OF\n              ORIGIN BASED ON THE DATE OF REISSUE.\n          B.AFTER DEPARTURE / PARTIALLY UTILISED TICKETS\n            AFTER COMMENCEMENT OF THE FIRST SECTOR OF THE\n            JOURNEY OR THE JOURNEY PERFORMED TILL THE\n            TURNAROUND / FARE BREAK POINT.\n              IN THE EVENT OF VOLUNTARY CHANGES AFTER\n              COMMENCEMENT OF TRAVEL THE FARES FOR THE\n              PASSENGER JOURNEY SHALL BE RECALCULATED FROM\n              THE POINT OF ORIGIN IN ACCORDANCE WITH THE\n              FARES IN EFFECT ON THE DATE OF ORIGINAL\n              TICKET ISSUANCE.\n              APPLICABLE CHANGE FEES TO BE COLLECTED.\n          C.FOR A PASSENGER NOT TO BE CONSIDERED A NO SHOW\n          THE TICKET HAS TO BE EXCHANGED AT LEAST A DAY\n          BEFORE THE SCHEDULED DEPARTURE DATE\n          --------------------------------------------------\n          CANCELLATION / REFUNDS\n          ... CANCELLATION / REFUND FEES ARE NOT\n              COMMISSIONABLE.\n          ... CANCELLATION FEE DOES NOT APPLY TO INFANT NOT\n              OCCUPYING A SEAT.\n          --------------------------------------------------\n          CANCELLATION / REFUNDS AGAINST UPGRADES -\n          IF THE UPGRADED TICKET IS SUBSEQUENTLY CANCELLED\n          THE ORIGINAL CHARGE WILL APPLY.\n          --------------------------------------------------\n          OUT OF SEQUENCE TICKETS -\n          UTILIZATION OF TICKETS OUT OF SEQUENCE IS NOT\n          PERMITTED IF IN ANY CASE TICKETS IS UTILIZED OUT\n          OF SEQUENCE NO REFUND OF FARE AND THE CARRIER\n          IMPOSED SURCHARGE -YR/YQ.\n          --------------------------------------------------\n          REFUNDABILITY OF K3 TAX IS AS PER THE LATEST\n          CIRCULAR ON K3 TAX\n          --------------------------------------------------\n          A.WHEN OUTBOUND AND INBOUND FARES ARE REFUNDABLE.\n            WHEN COMBINING FARES THAT HAVE CANCELLATION\n            FEES THE HIGHEST CANCELLATION FEE OF EACH\n            CANCELLED PRICING UNIT APPLIES.\n            1.BEFORE DEPARTURE / FULLY UNUTILISED TICKETS\n          ... DEDUCT THE APPLICABLE HIGHEST CANCELLATION\n              FEE FROM THE TOTAL OF THE BASE FARE AND\n              CARRIER IMPOSED SURCHARGE - YR.\n          ... REFUND THE RESIDUAL AMOUNT ALONG WITH THE\n              REFUNDABLE GOVERNMENT TAXES.\n          ... CARRIER IMPOSED SERVICE CHARGE - YQ IS NOT\n              REFUNDABLE.\n            2.AFTER DEPARTURE / PARTIALLY UTILISED TICKETS -\n              AFTER COMMENCEMENT OF THE FIRST SECTOR OF THE\n              JOURNEY.\n          ..... DEDUCT ONE WAY FARE WITH SAME RBD FOR THE\n          USED SECTOR.\n          ... COLLECT APPLICABLE CANCELLATION FEE AND\n              THE CARRIER IMPOSED SURCHARGE - YR FOR THE\n              JOURNEY PERFORMED. DEDUCT NON-REFUNDABLE\n              TAXES.\n          ... REFUND THE CARRIER IMPOSED SURCHARGE - YR AND\n              UNUTILISED GOVERNMENT TAXES FOR THE PORTION\n              OF THE JOURNEY NOT PERFORMED.\n          ... NO REFUND OF FARE AND CARRIER IMPOSED\n              SURCHARGE - YR IF JOURNEY PERFORMED BEYOND\n              THE TURNAROUND/FARE BREAK POINT.\n          ... CARRIER IMPOSED SERVICE CHARGE - YQ IS NOT\n              REFUNDABLE.\n          --------------------------------------------------\n          B.WHEN OUTBOUND AND INBOUND FARES ARE NON -\n            REFUNDABLE.\n          ... NO REFUND OF THE FARE AND CARRIER IMPOSED\n              FEES - YQ AND YR.\n          ... DEDUCT NON-REFUNDABLE TAXES.\n          ... IF NON- REFUNDABLE FARES REISSUED TO A\n              REFUNDABLE FARE THE ORIGINAL PAID FARE AND\n              CARRIER IMPOSED FEES - YQ AND YR WILL BE NON-\n              REFUNDABLE.\n          --------------------------------------------------\n          C.COMBINATION OF REFUNDABLE AND NON-REFUNDABLE\n            FARES.\n            1.BEFORE DEPARTURE/FULLY UNUTILISED TICKETS.\n          ... DEDUCT THE NON-REFUNDABLE FARE PAID AND THE\n              CANCELLATION FEE OF THE REFUNDABLE FARE.\n          ... DEDUCT NON-REFUNDABLE TAXES.\n          ... CARRIER IMPOSED FEES - YQ AND YR ARE NOT\n              REFUNDABLE.\n            2.AFTER DEPARTURE / PARTIALLY UTILISED TICKETS -\n              AFTER COMMENCEMENT OF THE FIRST SECTOR OF THE\n              JOURNEY.\n            2.1 IF OUTBOUND FARE COMPONENT IS NON-\n              REFUNDABLE.\n          ..... DEDUCT ONE WAY FARE WITH EQUAL OR\n                HIGHER RBD FOR THE USED SECTOR.\n          ..... COLLECT THE CANCELLATION FEE OF THE\n                REFUNDABLE FARE.\n          ..... DEDUCT NON-REFUNDABLE TAXES.\n          ..... CARRIER IMPOSED FEES YQ AND YR ARE NOT\n                REFUNDABLE.\n            2.2 IF INBOUND FARE COMPONENT IS NON-REFUNDABLE.\n          ..... NO REFUND OF THE FARE AND CARRIER IMPOSED\n                FEES - YQ AND YR.\n          ..... DEDUCT NON-REFUNDABLE TAXES.\n          ..... NO REFUND OF FARE AND CARRIER IMPOSED\n                SURCHARGE - YQ IF JOURNEY PERFORMED BEYOND\n                THE TURNAROUND/FARE BREAK POINT.\n          --------------------------------------------------\n          WAIVERS\n          1.WAIVED FOR DEATH OF PASSENGER OR IMMEDIATE\n          FAMILY MEMBER.\n            A COPY OF VALID DEATH CERTIFICATE ISSUED BY A\n            COMPETENT MEDICAL AUTHORITY IS REQUIRED.\n          2.NO WAIVER APPLICABLE FOR ILLNESS OF PASSENGER\n            OR FAMILY MEMBER.\n          3.CONTACT ET LOCAL OFFICE FOR WAIVERS DEFINED\n            ABOVE.\n          --------------------------------------------------\n          PER THE  US  D.O.T   RULE  FOR TICKETS PURCHASED\n          IN THE USA  FULL REFUND WITHOUT PENALTY  IS\n          PERMITTED IF REQUEST IS MADE WITHIN 24 HOURS OF\n          TICKET ISSUANCE\n          -------------------------------------------------\n            PENALITY WAIVER FOR REFUND\n          1.PER THE BRAZILIAN LEGISLATION FOR TICKETS\n          PURCHASED IN THE BRAZIL FULL REFUND WITHOUT\n          PENALTY IS PERMITTED IF REQUEST IS MADE WITHIN 24\n          HOURS OF TICKET ISSUANCE ON GDS.\n          2.PER THE BRAZILIAN LEGISLATION FOR TICKETS\n          PURCHASED IN THE BRAZIL FULL REFUND WITHOUT\n          PENALTY IS PERMITTED IF REQUEST IS MADE WITHIN 7\n          DAYS OF TICKET ISSUANCE VIA ANY ELECTRONIC\n          CHANNELS SUCH AS OTAS/PHONES/EMAIL/MOBILE/WEB.\nHIP/MILEAGE EXCEPTIONS\nUNLESS OTHERWISE SPECIFIED\n  THE HIGHER INTERMEDIATE POINT RULE DOES NOT APPLY FOR\n  CONNECTIONS.\n  AND - THE HIGHER INTERMEDIATE POINT RULE DOES NOT APPLY\n        FOR STOPOVERS.\nTICKET ENDORSEMENT\nUNLESS OTHERWISE SPECIFIED\n  THE ORIGINAL AND THE REISSUED TICKET MUST BE ANNOTATED -\n  NON-ENDO/PENALTIES APPLY - IN THE ENDORSEMENT BOX.",
                        "fareType": ""
                    }
                ],
                "miniRules": [
                    {
                        "changeAllowed": "true",
                        "cancelAllowed": "false",
                        "cancellationCharge": 0.00,
                        "exchangeCharge": 0.00,
                        "currency": "RUB",
                        "cat16InfoCancel": "false",
                        "cancelRemarks": "null",
                        "cat16InfoChange": "false",
                        "changeRemarks": "null",
                        "paxtype": "",
                        "applicability": "Chargeable",
                        "type": "Reissue"
                    },
                    {
                        "changeAllowed": "false",
                        "cancelAllowed": "true",
                        "cancellationCharge": 0.00,
                        "exchangeCharge": 0.00,
                        "currency": "RUB",
                        "cat16InfoCancel": "false",
                        "cancelRemarks": "null",
                        "cat16InfoChange": "false",
                        "changeRemarks": "null",
                        "paxtype": "",
                        "applicability": "Chargeable",
                        "type": "Cancellation"
                    },
                    {
                        "changeAllowed": "true",
                        "cancelAllowed": "false",
                        "cancellationCharge": 0.00,
                        "exchangeCharge": 0.00,
                        "currency": "RUB",
                        "cat16InfoCancel": "false",
                        "cancelRemarks": "null",
                        "cat16InfoChange": "false",
                        "changeRemarks": "null",
                        "paxtype": "",
                        "applicability": "Chargeable",
                        "type": "Reissue"
                    },
                    {
                        "changeAllowed": "false",
                        "cancelAllowed": "true",
                        "cancellationCharge": 0.00,
                        "exchangeCharge": 0.00,
                        "currency": "RUB",
                        "cat16InfoCancel": "false",
                        "cancelRemarks": "null",
                        "cat16InfoChange": "false",
                        "changeRemarks": "null",
                        "paxtype": "",
                        "applicability": "Chargeable",
                        "type": "Cancellation"
                    }
                ],
                "airBaggageDetails": [
                    {
                        "unitType": "KG",
                        "quantity": "2",
                        "origin": "BLR",
                        "destination": "ADD",
                        "airline": "ET",
                        "paxCode": "",
                        "paxType": "ADT",
                        "baggageInfo": "23 KG / 2 PC",
                        "cityPair": "BLRADD",
                        "cabinBaggageInfo": "7 KG / 1 PC"
                    },
                    {
                        "unitType": "KG",
                        "quantity": "2",
                        "origin": "ADD",
                        "destination": "DXB",
                        "airline": "ET",
                        "paxCode": "",
                        "paxType": "ADT",
                        "baggageInfo": "23 KG / 2 PC",
                        "cityPair": "ADDDXB",
                        "cabinBaggageInfo": "7 KG / 1 PC"
                    }
                ],
                "airCalculatedFlightFares": [
                    {
                        "singleAdtBaseFare": 36973.93,
                        "singleAdtTax": 32997.43,
                        "adtCount": 1,
                        "singleChdBaseFare": 0.0,
                        "singleChdTax": 0.0,
                        "chdCount": 0,
                        "singleInfBaseFare": 0.0,
                        "singleInfTax": 0,
                        "infCount": 0,
                        "totalBaseFare": 36973.93,
                        "totalTax": 32997.43,
                        "branchCurrency": "INR",
                        "singleAdtGST": 0.00,
                        "singleChdGST": 0.0,
                        "singleInfGST": 0.0
                    }
                ],
                "status": "UnConfirmed",
                "pnr": "null",
                "isLCC": "false",
                "isNDC": "false",
                "brandName": "",
                "passportRequiredAtTicketing": "false",
                "tktTimeLimit": "2026-04-21T23:59:00"
            }
        ],
        "errorMessage": "null",
        "errorDetails": "null"
    }
}

# %%
from langchain_text_splitters import RecursiveJsonSplitter

# %%
## create the text splitter
json_splitter = RecursiveJsonSplitter(max_chunk_size =200)

# %%
## return json dictionaries 
chunk_dict = json_splitter.split_json(json_data=json_data)
print(chunk_dict)
# Out:
# [{'statusCode': 200, 'message': 'POST Request successful.'}, {'result': {'flightPassengerList': [{'bookingId': 62649, 'referenceNumber': 'CFR042662649', 'title': 'Mr', 'firstName': 'Hem', 'lastName': 'Kamli', 'email': 'care@travelterminus.com', 'dob': '2013-11-20T00:00:00', 'gender': 'M', 'ffNumber': '', 'paxType': 'ADT', 'mobile': '9016888437', 'passportNumber': 'HEM123', 'passengerNationality': 'AL', 'passportDOI': '2025-12-03T00:00:00', 'passportDOE': '2026-12-31T00:00:00', 'passportIssuedCountry': 'IN', 'seatPref': '', 'mealPref': '', 'paxId': 222467, 'tickets': [], 'extraBaggage': []}]}}, {'result': {'clientFlightDetails': [{'searchIdentifier': '25be7b83-039b-4742-8d2f-682c299adb46', 'validatingCarrier': 'ET', 'travelDate': '2026-06-24T16:10:00', 'adtCount': 1, 'chdCount': 0, 'infCount': 0, 'totalFare': 69971.36, 'origin': 'BLR', 'destination': 'DXB', 'itineraryUniqueReference': 'ET691ET600', 'airFlightSegments': [{'airlinePnr': '', 'isReturn': 'false', 'origin': 'BLR', 'destina
# ...

# %%
display_chunks(chunk_dict)
# Out:
# Total number of chnuks: 4
# Chunk : 1 : Length : 2 chars
# {'statusCode': 200, 'message': 'POST Request successful.'}
#
# Chunk : 2 : Length : 1 chars
# {'result': {'flightPassengerList': [{'bookingId': 62649, 'referenceNumber': 'CFR042662649', 'title': 'Mr', 'firstName': 'Hem', 'lastName': 'Kamli', 'email': 'care@travelterminus.com', 'dob': '2013-11-20T00:00:00', 'gender': 'M', 'ffNumber': '', 'paxType': 'ADT', 'mobile': '9016888437', 'passportNumber': 'HEM123', 'passengerNationality': 'AL', 'passportDOI': '2025-12-03T00:00:00', 'passportDOE': '2026-12-31T00:00:00', 'passportIssuedCountry': 'IN', 'seatPref': '', 'mealPref': '', 'paxId': 222467, 'tickets': [], 'extraBaggage': []}]}}
#
# Chunk : 3 : Length : 1 chars
# ...
