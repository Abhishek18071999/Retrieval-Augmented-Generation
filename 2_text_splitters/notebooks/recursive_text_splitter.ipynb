# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text = """Hi how are you
My name is Abhishek Ahlawat The Great

I am teaching RAG
We are Learning about RAG"""

print(text)
# Out:
# Hi how are you
# My name is Abhishek Ahlawat The Great
#
# I am teaching RAG
# We are Learning about RAG

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 10, chunk_overlap =10)

# %%
splitter.split_text(text)
# Out:
# ['Hi how are',
#  'are you',
#  'My name',
#  'name is',
#  'Abhishek',
#  'Ahlawat',
#  'The Great',
#  'I am',
#  'teaching',
#  'RAG',
#  'We are',
#  'Learning',
#  'about RAG']

# %%
example_text = """Artificial intelligence is transforming technology and shaping the future.

Machine learning algorithms are becoming more sophisticated every day. 
Deep learning models can now process vast amounts of data efficiently.

Natural language processing has made significant strides in recent years.
Transformers architecture revolutionized the field in 2017.
Models like GPT and BERT have set new benchmarks.

Computer vision systems can now identify objects with remarkable accuracy.
Convolutional neural networks excel at image recognition tasks.
Self-driving cars rely heavily on advanced computer vision.

The impact of AI extends across multiple industries including healthcare, finance, and transportation.
Ethical considerations around AI development are becoming increasingly important.
Researchers are working on making AI systems more transparent and explainable."""

# %%
##creating the splitter
splitter = RecursiveCharacterTextSplitter(chunk_size = 100, chunk_overlap = 20)

# %%
chunks = splitter.split_text(example_text)

# %%
from termcolor import COLORS,colored
from random import choice

# %%
def display_chunks(chunks):
    colors_list = list(COLORS.keys())[2:8]
    print(f"Total Number of Chunks: {len(chunks)}")
    for num, chunk in enumerate(chunks, 1):
        print(f"Chunk {num}: Length {len(chunk)} chars")
        print(colored(text=chunk, color=choice(colors_list)), end="\n\n")

# %%
display_chunks(chunks)
# Out:
# Total Number of Chunks: 13
# Chunk 1: Length 74 chars
# Artificial intelligence is transforming technology and shaping the future.
#
# Chunk 2: Length 70 chars
# Machine learning algorithms are becoming more sophisticated every day.
#
# Chunk 3: Length 70 chars
# Deep learning models can now process vast amounts of data efficiently.
#
# Chunk 4: Length 73 chars
# Natural language processing has made significant strides in recent years.
#
# Chunk 5: Length 59 chars
# Transformers architecture revolutionized the field in 2017.
#
# Chunk 6: Length 49 chars
# Models like GPT and BERT have set new benchmarks.
#
# Chunk 7: Length 74 chars
# Computer vision systems can now identify objects with remarkable accuracy.
#
# Chunk 8: Length 63 chars
# Convolutional neural networks excel at image recognition tasks.
#
# Chunk 9: Length 59 chars
# Self-driving cars rely heavily on advanced computer vision.
#
# Chunk 10: Length 86 chars
# The impact of AI extends across multiple industries including healthcare, finance, and
#
# Chunk 11: Length 28 chars
# finance, and transportation.
#
# Chunk 12: Length 81 chars
# Ethical considerations around AI development are becoming increasingly important.
#
# Chunk 13: Length 78 chars
# Researchers are working on making AI systems more transparent and explainable.

# %% [markdown]
# ## Documents

# %%
from langchain_core.documents import Document
from pprint import pp

# %%
## create list of documents
list_of_text = [text, example_text]
docs = [Document(page_content=text, metadata={"source":"text","Author" : "Abhishek Ahlawat The Great"}) for text in list_of_text]

print(len(docs))
print(docs)
# Out:
# 2
# [Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Hi how are you\nMy name is Abhishek Ahlawat The Great\n\nI am teaching RAG\nWe are Learning about RAG'), Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Artificial intelligence is transforming technology and shaping the future.\n\nMachine learning algorithms are becoming more sophisticated every day. \nDeep learning models can now process vast amounts of data efficiently.\n\nNatural language processing has made significant strides in recent years.\nTransformers architecture revolutionized the field in 2017.\nModels like GPT and BERT have set new benchmarks.\n\nComputer vision systems can now identify objects with remarkable accuracy.\nConvolutional neural networks excel at image recognition tasks.\nSelf-driving cars rely heavily on advanced computer vision.\n\nThe impact of AI extends across multiple industries including healthcare, finance, and transportation.\nEthical considerations around AI development are becoming increasingly important.\nResearchers are working on making AI systems more transparent and explainable.')]

# %%
## split the documents
chunk_docs = splitter.split_documents(docs)

# %%
print(len(chunk_docs))
pp(chunk_docs)
# Out:
# 14
# [Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Hi how are you\nMy name is Abhishek Ahlawat The Great\n\nI am teaching RAG\nWe are Learning about RAG'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Artificial intelligence is transforming technology and shaping the future.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Machine learning algorithms are becoming more sophisticated every day.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Deep learning models can now process vast amounts of data efficiently.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Natural language processing has made significant strides in recent years.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Transformers architecture revolutionized the field in 2017.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Models like GPT and BERT have set new benchmarks.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Computer vision systems can now identify objects with remarkable accuracy.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Convolutional neural networks excel at image recognition tasks.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Self-driving cars rely heavily on advanced computer vision.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='The impact of AI extends across multiple industries including healthcare, finance, and'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='finance, and transportation.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Ethical considerations around AI development are becoming increasingly important.'),
#  Document(metadata={'source': 'text', 'Author': 'Abhishek Ahlawat The Great'}, page_content='Researchers are working on making AI systems more transparent and explainable.')]
